# %% [markdown]
# # Import All Relevant packages for extracting Data From Screener.in

# %%
import numpy as np # linear algebra
import pandas as pd # pandas for dataframe based data processing and CSV file I/O
import requests # for http requests
from bs4 import BeautifulSoup # for html parsing and scraping
import bs4
import json
from tidylib import tidy_document # for tidying incorrect html
import pandas as pd
import time
from selenium import webdriver
import pickle
import selenium.webdriver

# %%
import pandas as pd
read_nifty=pd.read_csv('data/NSE_500_Output2.csv')
#read_nifty.head()
#read_nifty = read_nifty[read_nifty.Industry != 'FINANCIAL SERVICES']
#read_nifty = read_nifty[read_nifty.Industry != 'CONSTRUCTION']
symbol_list=read_nifty['Symbol'].unique().tolist()
len(symbol_list)
# Out:
# 365

# %%
##################With Pickle Sabeeh1983
#symbol_list=['INFY','TCS','BDL','ABBOTINDIA']
z_file_standalone=pd.DataFrame()
q_file_standalone=pd.DataFrame()
y_file_standalone=pd.DataFrame()
s_file_standalone=pd.DataFrame()
q_file_name_standalone="data/Quarter_Ticker_nifty500_standalone"+'.csv'
y_file_name_standalone="data/Yearly_Ticker_nifty500_standalone"+'.csv'
z_file_name_standalone="data/Peer_Ticker_nifty500_standalone"+'.csv'
s_file_name_standalone='data/Share_Holding_nifty500_standalone'+'.csv'
#symbol_list=['INFY','RELIANCE']
from selenium import webdriver
folder_to_save='C:\\Users\\sashhar\\Desktop\\Quantopian\\Data\\'
count=1
for symbol in symbol_list:
    print("Now processing for Symbol: ",count,"  ", symbol)
    driver = webdriver.Chrome('C:\\Users\\sashhar\\Desktop\\Quantopian\\driver\\chromedriver.exe')
    driver.get("http://www.screener.in") 
    cookies = pickle.load(open("sabeeh1983_cookie.pkl", "rb"))
    for cookie in cookies: 
        driver.add_cookie(cookie)
    url="https://www.screener.in/company/"+symbol
    #for i in range(0,3):
    #    while True:
    #        try:
    #            driver.get(url)
    #        except SomeSpecificException:
    #            print("Got Exception. Now Retrying")
    #            continue
    #        break
    driver.get(url)
    content = BeautifulSoup(driver.page_source, "html.parser")
    #company_name=content.find("a",{"class":'active'}).text
    try:
        z2=content.find("section",{"id":'peers'}).find("div",{"id":'peers-table-placeholder'}).find_all('table')
        z3=pd.read_html(str(z2))[0]
        z3['Ticker']=symbol
        z3['Type']="Peer_Comparison"
        company_name=content.find("a",{"class":'active'}).text
        z3['Company_Name']=company_name
        #print(z3.head())
        z_file_standalone=z_file_standalone.append(z3)
    except:
        print("Error getting peers data for symbol:",symbol)
    try:
        quarter_income_table=content.find("section",{"id":'quarters'}).find_all('table')
        quarter_income_df = pd.read_html(str(quarter_income_table))[0].T
        quarter_income_df.columns = quarter_income_df.iloc[0]
        quarter_income_df=quarter_income_df.drop(quarter_income_df.index[0])
        quarter_income_df.index.names=['Date']
        quarter_income_df['Ticker']=symbol
        quarter_income_df['Type']="Quarterly_Income_Statement"
        q_file_standalone=q_file_standalone.append(quarter_income_df)
    except:
        print("Error Getting Quarter data for symbol:",symbol)
    try:
        shareholding_table=content.find("section",{"id":'shareholding'}).find_all('table')
        shareholding_table_df = pd.read_html(str(shareholding_table))[0].T
        shareholding_table_df.columns = shareholding_table_df.iloc[0]
        shareholding_table_df=shareholding_table_df.drop(shareholding_table_df.index[0])
        shareholding_table_df.index.names=['Date']
        shareholding_table_df['Ticker']=symbol
        shareholding_table_df['Type']="Shareholding_Pattern"  
        #shareholding_table_df['Company_Name']=company_name
        s_file_standalone=s_file_standalone.append(shareholding_table_df)
    except:
        print("Error Getting Shareholder data for symbol:", symbol)
    try:
        income_table=content.find("section",{"id":'profit-loss'}).find_all('table')
        income_statement_df = pd.read_html(str(income_table))[0]
        income_statement_df.columns.values[0] = "KPI"
        income_statement_df.set_index("KPI",inplace=True)
        column_list = income_statement_df.columns.tolist()
        if 'TTM' in column_list :
            TTM=income_statement_df['TTM']
            income_statement_df=income_statement_df.drop(columns=['TTM'])
            income_statement_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
            income_statement_df['TTM']=TTM
        else:
            income_statement_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
        income_statement_df['Ticker']=symbol
        income_statement_df['Type']="Income_Statement"
        income_statement_df=income_statement_df.loc[:,~income_statement_df.columns.duplicated()]
        #income_statement_df['Company_Name']=company_name
        y_file_standalone=y_file_standalone.append(income_statement_df)
    except:
        print("Error Getting Income Statement for symbol:",symbol)
    try:
        balance_sheet_table=content.find("section",{"id":'balance-sheet'}).find_all('table')
        balance_sheet_df = pd.read_html(str(balance_sheet_table))[0]
        balance_sheet_df.columns.values[0] = "KPI"
        balance_sheet_df.set_index("KPI",inplace=True)
        column_list = balance_sheet_df.columns.tolist()
        if 'TTM' in column_list :
            TTM=balance_sheet_df['TTM']
            balance_sheet_df=balance_sheet_df.drop(columns=['TTM'])
            balance_sheet_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
            balance_sheet_df['TTM']=TTM
        else:
            balance_sheet_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
        balance_sheet_df['Ticker']=symbol
        balance_sheet_df['Type']="Balance_Sheet"
        balance_sheet_df=balance_sheet_df.loc[:,~balance_sheet_df.columns.duplicated()]
        #balance_sheet_df['Company_Name']=company_name
        y_file_standalone=y_file_standalone.append(balance_sheet_df)
    except:
        print("Error Getting Balance Sheet Data for symbol:", symbol)
    try:
        cash_flow_table=content.find("section",{"id":'cash-flow'}).find_all('table')
        cash_flow_df = pd.read_html(str(cash_flow_table))[0]
        cash_flow_df.columns.values[0] = "KPI"
        cash_flow_df.set_index("KPI",inplace=True)
        column_list = cash_flow_df.columns.tolist()
        if 'TTM' in column_list :
            TTM=cash_flow_df['TTM']
            cash_flow_df=cash_flow_df.drop(columns=['TTM'])
            cash_flow_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
            cash_flow_df['TTM']=TTM
        else:
            cash_flow_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
        cash_flow_df['Ticker']=symbol
        cash_flow_df['Type']="Cash_Flow"
        cash_flow_df=cash_flow_df.loc[:,~cash_flow_df.columns.duplicated()]
        #cash_flow_df['Company_Name']=company_name
        y_file_standalone=y_file_standalone.append(cash_flow_df)   
    except:
        print("Error getting Cash Flow Data for symbol:", symbol)
    count=count+1
    driver.quit()
    time.sleep(1.5)
# Out:
# Now processing for Symbol:  1    ACC
# Now processing for Symbol:  2    ABBOTINDIA
# Now processing for Symbol:  3    ADANIGREEN
# Now processing for Symbol:  4    ADANIPORTS
# Now processing for Symbol:  5    ADANITRANS
# Now processing for Symbol:  6    ALKEM
# Now processing for Symbol:  7    AMBUJACEM
# Now processing for Symbol:  8    ASIANPAINT
# Now processing for Symbol:  9    AUROPHARMA
# Now processing for Symbol:  10    DMART
# Now processing for Symbol:  11    BAJAJ-AUTO
# Now processing for Symbol:  12    BERGEPAINT
# Now processing for Symbol:  13    BPCL
# Now processing for Symbol:  14    BHARTIARTL
# Now processing for Symbol:  15    BIOCON
# Now processing for Symbol:  16    BOSCHLTD
# Now processing for Symbol:  17    BRITANNIA
# Now processing for Symbol:  18    CADILAHC
# Now processing for Symbol:  19    CIPLA
# Now processing for Symbol:  20    COALINDIA
# Now processing for Symbol:  21    CONCOR
# Now processing for Symbol:  22    DABUR
# Now processing for Symbol:  23    DIVISLAB
# Now processing for Symbol:  24    DRREDDY
# Now processing for Symbol:  25    EICHERMOT
# Now processing for Symbol:  26    GAIL
# Now processing for Symbol:  27    GODREJCP
# Now processing for Symbol:  28    GRASIM
# Now processing for Symbol:  29    HCLTECH
# Now processing for Symbol:  30    HAVELLS
# Now processing for Symbol:  31    HEROMOTOCO
# Now processing for Symbol:  32    HINDALCO
# Now processing for Symbol:  33    HINDPETRO
# Now processing for Symbol:  34    HINDUNILVR
# Now processing for Symbol:  35    HINDZINC
# Now processing for Symbol:  36    ITC
# Now processing for Symbol:  37    IOC
# Now processing for Symbol:  38    IGL
# Now processing for Symbol:  39    NAUKRI
# Now processing for Symbol:  40    INFY
# Now processing for Symbol:  41    INDIGO
# Now processing for Symbol:  42    JSWSTEEL
# Now processing for Symbol:  43    LTI
# Now processing for Symbol:  44    LUPIN
# Now processing for Symbol:  45    M&M
# Now processing for Symbol:  46    MARICO
# Now processing for Symbol:  47    MARUTI
# Now processing for Symbol:  48    MOTHERSUMI
# Now processing for Symbol:  49    NMDC
# Now processing for Symbol:  50    NTPC
# Now processing for Symbol:  51    NESTLEIND
# Now processing for Symbol:  52    ONGC
# Now processing for Symbol:  53    OFSS
# Now processing for Symbol:  54    PETRONET
# Now processing for Symbol:  55    PIDILITIND
# Now processing for Symbol:  56    POWERGRID
# Now processing for Symbol:  57    PGHH
# Now processing for Symbol:  58    RELIANCE
# Now processing for Symbol:  59    SHREECEM
# Now processing for Symbol:  60    SIEMENS
# Now processing for Symbol:  61    SUNPHARMA
# Now processing for Symbol:  62    TCS
# Now processing for Symbol:  63    TATACONSUM
# Now processing for Symbol:  64    TATAMOTORS
# Now processing for Symbol:  65    TATASTEEL
# Now processing for Symbol:  66    TECHM
# Now processing for Symbol:  67    TITAN
# Now processing for Symbol:  68    TORNTPHARM
# Now processing for Symbol:  69    UPL
# Now processing for Symbol:  70    ULTRACEMCO
# Now processing for Symbol:  71    UBL
# Now processing for Symbol:  72    MCDOWELL-N
# Now processing for Symbol:  73    WIPRO
# Now processing for Symbol:  74    3MINDIA
# Now processing for Symbol:  75    ABB
# Now processing for Symbol:  76    AIAENG
# Now processing for Symbol:  77    AARTIIND
# Now processing for Symbol:  78    ADANIENT
# Now processing for Symbol:  79    ADANIGAS
# Now processing for Symbol:  80    ABFRL
# Now processing for Symbol:  81    AJANTPHARM
# Now processing for Symbol:  82    AKZOINDIA
# Now processing for Symbol:  83    APLLTD
# Now processing for Symbol:  84    AMARAJABAT
# Now processing for Symbol:  85    APOLLOHOSP
# Now processing for Symbol:  86    APOLLOTYRE
# Now processing for Symbol:  87    ASHOKLEY
# Now processing for Symbol:  88    ASTRAZEN
# Now processing for Symbol:  89    ASTRAL
# Now processing for Symbol:  90    ATUL
# Now processing for Symbol:  91    BALKRISIND
# Now processing for Symbol:  92    BATAINDIA
# Now processing for Symbol:  93    BAYERCROP
# Now processing for Symbol:  94    BEL
# Now processing for Symbol:  95    BHARATFORG
# Now processing for Symbol:  96    BHEL
# Now processing for Symbol:  97    BBTC
# Now processing for Symbol:  98    CESC
# Now processing for Symbol:  99    CASTROLIND
# Now processing for Symbol:  100    COROMANDEL
# Now processing for Symbol:  101    CROMPTON
# Now processing for Symbol:  102    CUMMINSIND
# Now processing for Symbol:  103    DALBHARAT
# Now processing for Symbol:  104    LALPATHLAB
# Now processing for Symbol:  105    EMAMILTD
# Now processing for Symbol:  106    ENDURANCE
# Now processing for Symbol:  107    ERIS
# Now processing for Symbol:  108    ESCORTS
# Now processing for Symbol:  109    EXIDEIND
# Now processing for Symbol:  110    FORTIS
# Now processing for Symbol:  111    FRETAIL
# Now processing for Symbol:  112    GILLETTE
# Now processing for Symbol:  113    GLAXO
# Now processing for Symbol:  114    GLENMARK
# Now processing for Symbol:  115    GODREJAGRO
# Now processing for Symbol:  116    GODREJIND
# Now processing for Symbol:  117    GUJGASLTD
# Now processing for Symbol:  118    GSPL
# Now processing for Symbol:  119    HATSUN
# Now processing for Symbol:  120    HAL
# Now processing for Symbol:  121    HONAUT
# Now processing for Symbol:  122    ITI
# Now processing for Symbol:  123    INDHOTEL
# Now processing for Symbol:  124    IRCTC
# Now processing for Symbol:  125    IPCALAB
# Now processing for Symbol:  126    JKCEMENT
# Now processing for Symbol:  127    JSWENERGY
# Now processing for Symbol:  128    JINDALSTEL
# Now processing for Symbol:  129    JUBLFOOD
# Now processing for Symbol:  130    KANSAINER
# Now processing for Symbol:  131    LTTS
# Now processing for Symbol:  132    MRF
# Now processing for Symbol:  133    MGL
# Now processing for Symbol:  134    MRPL
# Now processing for Symbol:  135    METROPOLIS
# Now processing for Symbol:  136    MINDTREE
# Now processing for Symbol:  137    MINDAIND
# Now processing for Symbol:  138    MPHASIS
# Now processing for Symbol:  139    NATCOPHARM
# Now processing for Symbol:  140    NHPC
# Now processing for Symbol:  141    NLCINDIA
# Now processing for Symbol:  142    NATIONALUM
# Now processing for Symbol:  143    NAVINFLUOR
# Now processing for Symbol:  144    OIL
# Now processing for Symbol:  145    PIIND
# Now processing for Symbol:  146    PAGEIND
# Now processing for Symbol:  147    PFIZER
# Now processing for Symbol:  148    POLYCAB
# Now processing for Symbol:  149    RAJESHEXPO
# Now processing for Symbol:  150    RELAXO
# Now processing for Symbol:  151    SJVN
# Now processing for Symbol:  152    SKFINDIA
# Now processing for Symbol:  153    SRF
# Now processing for Symbol:  154    SANOFI
# Now processing for Symbol:  155    SCHAEFFLER
# Now processing for Symbol:  156    SFL
# Now processing for Symbol:  157    SOLARINDS
# Now processing for Symbol:  158    SAIL
# Now processing for Symbol:  159    SUMICHEM
# Now processing for Symbol:  160    SUNDRMFAST
# Now processing for Symbol:  161    SUPREMEIND
# Now processing for Symbol:  162    SYMPHONY
# Now processing for Symbol:  163    SYNGENE
# Now processing for Symbol:  164    TTKPRESTIG
# Now processing for Symbol:  165    TVSMOTOR
# Now processing for Symbol:  166    TATACHEM
# Now processing for Symbol:  167    TATACOMM
# Now processing for Symbol:  168    TATAPOWER
# Now processing for Symbol:  169    RAMCOCEM
# Now processing for Symbol:  170    THERMAX
# Now processing for Symbol:  171    TORNTPOWER
# Now processing for Symbol:  172    TRENT
# Now processing for Symbol:  173    TIINDIA
# Now processing for Symbol:  174    VGUARD
# Now processing for Symbol:  175    VBL
# Now processing for Symbol:  176    VINATIORGA
# Now processing for Symbol:  177    VOLTAS
# Now processing for Symbol:  178    WABCOINDIA
# Now processing for Symbol:  179    WHIRLPOOL
# Now processing for Symbol:  180    ZYDUSWELL
# Now processing for Symbol:  181    POWERINDIA
# Now processing for Symbol:  182    APLAPOLLO
# Now processing for Symbol:  183    AARTIDRUGS
# Now processing for Symbol:  184    ADVENZYMES
# Now processing for Symbol:  185    AEGISCHEM
# Now processing for Symbol:  186    AFFLE
# Now processing for Symbol:  187    ALEMBICLTD
# Now processing for Symbol:  188    ALKYLAMINE
# Now processing for Symbol:  189    ALLCARGO
# Now processing for Symbol:  190    ALOKINDS
# Now processing for Symbol:  191    AMBER
# Now processing for Symbol:  192    ASTERDM
# Now processing for Symbol:  193    AVANTIFEED
# Now processing for Symbol:  194    BASF
# Now processing for Symbol:  195    BEML
# Now processing for Symbol:  196    BAJAJCON
# Now processing for Symbol:  197    BAJAJELEC
# Now processing for Symbol:  198    BALMLAWRIE
# Now processing for Symbol:  199    BALRAMCHIN
# Now processing for Symbol:  200    BDL
# Now processing for Symbol:  201    BHARATRAS
# Error Getting Shareholder data for symbol: BHARATRAS
# Now processing for Symbol:  202    BIRLACORPN
# Now processing for Symbol:  203    BSOFT
# Now processing for Symbol:  204    BLISSGVS
# Now processing for Symbol:  205    BLUEDART
# Now processing for Symbol:  206    BLUESTARCO
# Now processing for Symbol:  207    CCL
# Now processing for Symbol:  208    CAPLIPOINT
# Now processing for Symbol:  209    CARBORUNIV
# Now processing for Symbol:  210    CEATLTD
# Now processing for Symbol:  211    CENTURYPLY
# Now processing for Symbol:  212    CENTURYTEX
# Now processing for Symbol:  213    CHALET
# Now processing for Symbol:  214    CHAMBLFERT
# Now processing for Symbol:  215    CHENNPETRO
# Now processing for Symbol:  216    COCHINSHIP
# Now processing for Symbol:  217    CYIENT
# Now processing for Symbol:  218    DCMSHRIRAM
# Now processing for Symbol:  219    DEEPAKNTR
# Now processing for Symbol:  220    DELTACORP
# Now processing for Symbol:  221    DHANUKA
# Now processing for Symbol:  222    DCAL
# Now processing for Symbol:  223    DIXON
# Now processing for Symbol:  224    EIDPARRY
# Now processing for Symbol:  225    EIHOTEL
# Now processing for Symbol:  226    ESABINDIA
# Now processing for Symbol:  227    ELGIEQUIP
# Now processing for Symbol:  228    ESSELPACK
# Error getting peers data for symbol: ESSELPACK
# Error Getting Quarter data for symbol: ESSELPACK
# Error Getting Shareholder data for symbol: ESSELPACK
# Error Getting Income Statement for symbol: ESSELPACK
# Error Getting Balance Sheet Data for symbol: ESSELPACK
# Error getting Cash Flow Data for symbol: ESSELPACK
# Now processing for Symbol:  229    FDC
# Now processing for Symbol:  230    FINEORG
# Now processing for Symbol:  231    FINCABLES
# Now processing for Symbol:  232    FINPIPE
# Now processing for Symbol:  233    FSL
# Now processing for Symbol:  234    GEPIL
# Now processing for Symbol:  235    GHCL
# Now processing for Symbol:  236    GMMPFAUDLR
# Now processing for Symbol:  237    GALAXYSURF
# Now processing for Symbol:  238    GRSE
# Now processing for Symbol:  239    GARFIBRES
# Now processing for Symbol:  240    GODFRYPHLP
# Now processing for Symbol:  241    GRANULES
# Now processing for Symbol:  242    GRAPHITE
# Now processing for Symbol:  243    GESHIP
# Now processing for Symbol:  244    GREAVESCOT
# Now processing for Symbol:  245    GRINDWELL
# Now processing for Symbol:  246    GUJALKALI
# Now processing for Symbol:  247    GAEL
# Now processing for Symbol:  248    FLUOROCHEM
# Now processing for Symbol:  249    GMDCLTD
# Now processing for Symbol:  250    GNFC
# Now processing for Symbol:  251    GPPL
# Now processing for Symbol:  252    GSFC
# Now processing for Symbol:  253    GULFOILLUB
# Now processing for Symbol:  254    HEG
# Now processing for Symbol:  255    HEIDELBERG
# Now processing for Symbol:  256    HERITGFOOD
# Now processing for Symbol:  257    HSCL
# Now processing for Symbol:  258    HINDCOPPER
# Now processing for Symbol:  259    PAPERPROD
# Error getting peers data for symbol: PAPERPROD
# Error Getting Quarter data for symbol: PAPERPROD
# Error Getting Shareholder data for symbol: PAPERPROD
# Error Getting Income Statement for symbol: PAPERPROD
# Error Getting Balance Sheet Data for symbol: PAPERPROD
# Error getting Cash Flow Data for symbol: PAPERPROD
# Now processing for Symbol:  260    IFBIND
# Now processing for Symbol:  261    IOLCP
# Now processing for Symbol:  262    INDIACEM
# Now processing for Symbol:  263    INDIAMART
# Now processing for Symbol:  264    INDOCO
# Now processing for Symbol:  265    INFIBEAM
# Now processing for Symbol:  266    INGERRAND
# Now processing for Symbol:  267    JBCHEPHARM
# Now processing for Symbol:  268    JKLAKSHMI
# Now processing for Symbol:  269    JKPAPER
# Now processing for Symbol:  270    JKTYRE
# Now processing for Symbol:  271    JTEKTINDIA
# Now processing for Symbol:  272    JAICORPLTD
# Now processing for Symbol:  273    JAMNAAUTO
# Now processing for Symbol:  274    JINDALSAW
# Now processing for Symbol:  275    JSLHISAR
# Now processing for Symbol:  276    JSL
# Now processing for Symbol:  277    JCHAC
# Now processing for Symbol:  278    JUSTDIAL
# Now processing for Symbol:  279    JYOTHYLAB
# Now processing for Symbol:  280    KEI
# Now processing for Symbol:  281    KRBL
# Now processing for Symbol:  282    KSB
# Now processing for Symbol:  283    KALPATPOWR
# Now processing for Symbol:  284    KSCL
# Now processing for Symbol:  285    LAOPALA
# Now processing for Symbol:  286    LAXMIMACH
# Now processing for Symbol:  287    LAURUSLABS
# Now processing for Symbol:  288    LEMONTREE
# Now processing for Symbol:  289    LINDEINDIA
# Now processing for Symbol:  290    LUXIND
# Now processing for Symbol:  291    MOIL
# Now processing for Symbol:  292    MAHSCOOTER
# Now processing for Symbol:  293    MAHSEAMLES
# Now processing for Symbol:  294    MHRIL
# Now processing for Symbol:  295    MAHLOG
# Now processing for Symbol:  296    MINDACORP
# Now processing for Symbol:  297    MIDHANI
# Now processing for Symbol:  298    NESCO
# Now processing for Symbol:  299    NOCIL
# Now processing for Symbol:  300    NH
# Now processing for Symbol:  301    NFL
# Now processing for Symbol:  302    NILKAMAL
# Now processing for Symbol:  303    ORIENTCEM
# Error getting peers data for symbol: ORIENTCEM
# Now processing for Symbol:  304    ORIENTELEC
# Now processing for Symbol:  305    ORIENTREF
# Now processing for Symbol:  306    PTC
# Now processing for Symbol:  307    PERSISTENT
# Now processing for Symbol:  308    PHILIPCARB
# Now processing for Symbol:  309    POLYMED
# Now processing for Symbol:  310    POLYPLEX
# Now processing for Symbol:  311    PRAJIND
# Now processing for Symbol:  312    PRSMJOHNSN
# Now processing for Symbol:  313    PGHL
# Now processing for Symbol:  314    QUESS
# Now processing for Symbol:  315    RITES
# Now processing for Symbol:  316    RADICO
# Now processing for Symbol:  317    RAIN
# Now processing for Symbol:  318    RALLIS
# Now processing for Symbol:  319    RCF
# Now processing for Symbol:  320    RATNAMANI
# Now processing for Symbol:  321    RAYMOND
# Now processing for Symbol:  322    REDINGTON
# Now processing for Symbol:  323    SCHNEIDER
# Now processing for Symbol:  324    SIS
# Now processing for Symbol:  325    SEQUENT
# Now processing for Symbol:  326    SHILPAMED
# Now processing for Symbol:  327    SCI
# Now processing for Symbol:  328    SHOPERSTOP
# Now processing for Symbol:  329    SOLARA
# Now processing for Symbol:  330    SONATSOFTW
# Now processing for Symbol:  331    SPICEJET
# Now processing for Symbol:  332    STARCEMENT
# Now processing for Symbol:  333    STRTECH
# Error getting peers data for symbol: STRTECH
# Error Getting Quarter data for symbol: STRTECH
# Error Getting Shareholder data for symbol: STRTECH
# Error Getting Income Statement for symbol: STRTECH
# Error Getting Balance Sheet Data for symbol: STRTECH
# Error getting Cash Flow Data for symbol: STRTECH
# Now processing for Symbol:  334    STAR
# Now processing for Symbol:  335    SUDARSCHEM
# Now processing for Symbol:  336    SPARC
# Now processing for Symbol:  337    SUPRAJIT
# Now processing for Symbol:  338    SUPPETRO
# Now processing for Symbol:  339    SUVENPHAR
# Now processing for Symbol:  340    SWARAJENG
# Now processing for Symbol:  341    TCIEXP
# Now processing for Symbol:  342    TCNSBRANDS
# Now processing for Symbol:  343    TASTYBITE
# Now processing for Symbol:  344    TATACOFFEE
# Now processing for Symbol:  345    TATAELXSI
# Now processing for Symbol:  346    TATASTLBSL
# Now processing for Symbol:  347    TEAMLEASE
# Now processing for Symbol:  348    THYROCARE
# Now processing for Symbol:  349    TIMKEN
# Now processing for Symbol:  350    UFLEX
# Now processing for Symbol:  351    VMART
# Now processing for Symbol:  352    VIPIND
# Now processing for Symbol:  353    VRLLOG
# Now processing for Symbol:  354    VSTIND
# Now processing for Symbol:  355    VAIBHAVGBL
# Now processing for Symbol:  356    VAKRANGEE
# Now processing for Symbol:  357    VTL
# Now processing for Symbol:  358    VARROC
# Now processing for Symbol:  359    VENKEYS
# Now processing for Symbol:  360    WELCORP
# Now processing for Symbol:  361    WELSPUNIND
# Now processing for Symbol:  362    WESTLIFE
# Now processing for Symbol:  363    WOCKPHARMA
# Now processing for Symbol:  364    ZENSARTECH
# Now processing for Symbol:  365    ECLERX

# %%
z_file_standalone.to_csv(z_file_name_standalone)
q_file_standalone.to_csv(q_file_name_standalone)
y_file_standalone.to_csv(y_file_name_standalone)
s_file_standalone.to_csv(s_file_name_standalone)
z_file_standalone[z_file_standalone['Name']==z_file_standalone['Company_Name']].to_csv('data/Peer_Ticker_nifty500_stand_cleaned.csv')

# %%
##################With Pickle Sabeeh1983
#symbol_list=['INFY','TCS','BDL','ABBOTINDIA']
z_file_consolidated=pd.DataFrame()
q_file_consolidated=pd.DataFrame()
y_file_consolidated=pd.DataFrame()
s_file_consolidated=pd.DataFrame()
q_file_name_consolidated="data/Quarter_Ticker_nifty500_consolidated"+'.csv'
y_file_name_consolidated="data/Yearly_Ticker_nifty500_consolidated"+'.csv'
z_file_name_consolidated="data/Peer_Ticker_nifty500_consolidated"+'.csv'
s_file_name_consolidated='data/Share_Holding_nifty500_consolidated'+'.csv'
#symbol_list=['INFY','RELIANCE']
from selenium import webdriver
folder_to_save='C:\\Users\\sashhar\\Desktop\\Quantopian\\Data\\'
count=1
for symbol in symbol_list:
    print("Now processing for Symbol: ",count,"  ", symbol)
    driver = webdriver.Chrome('C:\\Users\\sashhar\\Desktop\\Quantopian\\driver\\chromedriver.exe')
    driver.get("http://www.screener.in") 
    cookies = pickle.load(open("sabeeh1983_cookies.pkl", "rb"))
    for cookie in cookies: 
        driver.add_cookie(cookie)
    url="https://www.screener.in/company/"+symbol+"/consolidated/"
    driver.get(url)
    content = BeautifulSoup(driver.page_source, "html.parser")
    #company_name=content.find("a",{"class":'active'}).text
    try:
        z2=content.find("section",{"id":'peers'}).find("div",{"id":'peers-table-placeholder'}).find_all('table')
        z3=pd.read_html(str(z2))[0]
        z3['Ticker']=symbol
        z3['Type']="Peer_Comparison"
        company_name=content.find("a",{"class":'active'}).text
        z3['Company_Name']=company_name
        #print(z3.head())
        z_file_consolidated=z_file_consolidated.append(z3)
    except:
        print("Error getting peers data for symbol:",symbol)
    try:
        quarter_income_table=content.find("section",{"id":'quarters'}).find_all('table')
        quarter_income_df = pd.read_html(str(quarter_income_table))[0].T
        quarter_income_df.columns = quarter_income_df.iloc[0]
        quarter_income_df=quarter_income_df.drop(quarter_income_df.index[0])
        quarter_income_df.index.names=['Date']
        quarter_income_df['Ticker']=symbol
        quarter_income_df['Type']="Quarterly_Income_Statement"
        q_file_consolidated=q_file_consolidated.append(quarter_income_df)
    except:
        print("Error Getting Quarter data for symbol:",symbol)
    try:
        shareholding_table=content.find("section",{"id":'shareholding'}).find_all('table')
        shareholding_table_df = pd.read_html(str(shareholding_table))[0].T
        shareholding_table_df.columns = shareholding_table_df.iloc[0]
        shareholding_table_df=shareholding_table_df.drop(shareholding_table_df.index[0])
        shareholding_table_df.index.names=['Date']
        shareholding_table_df['Ticker']=symbol
        shareholding_table_df['Type']="Shareholding_Pattern"  
        #shareholding_table_df['Company_Name']=company_name
        s_file_consolidated=s_file_consolidated.append(shareholding_table_df)
    except:
        print("Error Getting Shareholder data for symbol:", symbol)
    try:
        income_table=content.find("section",{"id":'profit-loss'}).find_all('table')
        income_statement_df = pd.read_html(str(income_table))[0]
        income_statement_df.columns.values[0] = "KPI"
        income_statement_df.set_index("KPI",inplace=True)
        column_list = income_statement_df.columns.tolist()
        if 'TTM' in column_list :
            TTM=income_statement_df['TTM']
            income_statement_df=income_statement_df.drop(columns=['TTM'])
            income_statement_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
            income_statement_df['TTM']=TTM
        else:
            income_statement_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
        income_statement_df['Ticker']=symbol
        income_statement_df['Type']="Income_Statement"
        income_statement_df=income_statement_df.loc[:,~income_statement_df.columns.duplicated()]
        #income_statement_df['Company_Name']=company_name
        y_file_consolidated=y_file_consolidated.append(income_statement_df)
    except:
        print("Error Getting Income Statement for symbol:",symbol)
    try:
        balance_sheet_table=content.find("section",{"id":'balance-sheet'}).find_all('table')
        balance_sheet_df = pd.read_html(str(balance_sheet_table))[0]
        balance_sheet_df.columns.values[0] = "KPI"
        balance_sheet_df.set_index("KPI",inplace=True)
        column_list = balance_sheet_df.columns.tolist()
        if 'TTM' in column_list :
            TTM=balance_sheet_df['TTM']
            balance_sheet_df=balance_sheet_df.drop(columns=['TTM'])
            balance_sheet_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
            balance_sheet_df['TTM']=TTM
        else:
            balance_sheet_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
        balance_sheet_df['Ticker']=symbol
        balance_sheet_df['Type']="Balance_Sheet"
        balance_sheet_df=balance_sheet_df.loc[:,~balance_sheet_df.columns.duplicated()]
        #balance_sheet_df['Company_Name']=company_name
        y_file_consolidated=y_file_consolidated.append(balance_sheet_df)
    except:
        print("Error Getting Balance Sheet Data for symbol:", symbol)
    try:
        cash_flow_table=content.find("section",{"id":'cash-flow'}).find_all('table')
        cash_flow_df = pd.read_html(str(cash_flow_table))[0]
        cash_flow_df.columns.values[0] = "KPI"
        cash_flow_df.set_index("KPI",inplace=True)
        column_list = cash_flow_df.columns.tolist()
        if 'TTM' in column_list :
            TTM=cash_flow_df['TTM']
            cash_flow_df=cash_flow_df.drop(columns=['TTM'])
            cash_flow_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
            cash_flow_df['TTM']=TTM
        else:
            cash_flow_df.rename(columns = lambda x: x.split(' ')[1], inplace=True)
        cash_flow_df['Ticker']=symbol
        cash_flow_df['Type']="Cash_Flow"
        cash_flow_df=cash_flow_df.loc[:,~cash_flow_df.columns.duplicated()]
        #cash_flow_df['Company_Name']=company_name
        y_file_consolidated=y_file_consolidated.append(cash_flow_df)   
    except:
        print("Error getting Cash Flow Data for symbol:", symbol)
    count=count+1
    driver.quit()
    time.sleep(1.5)

# %%
z_file_consolidated.to_csv(z_file_name_consolidated)
q_file_consolidated.to_csv(q_file_name_consolidated)
y_file_consolidated.to_csv(y_file_name_consolidated)
s_file_consolidated.to_csv(s_file_name_consolidated)

# %%
q_file_name_standalone="data/Quarter_Ticker_nifty500_standalone"+'.csv'
y_file_name_standalone="data/Yearly_Ticker_nifty500_standalone"+'.csv'
z_file_name_standalone="data/Peer_Ticker_nifty500_standalone"+'.csv'
s_file_name_standalone='data/Share_Holding_nifty500_standalone'+'.csv'
z_file_consolidated=pd.read_csv(z_file_name_consolidated)
y_file_consolidated=pd.read_csv(y_file_name_consolidated)
q_file_consolidated=pd.read_csv(q_file_name_consolidated)
s_file_consolidated=pd.read_csv(s_file_name_consolidated)
z_file_standalone=pd.read_csv(z_file_name_standalone)
q_file_standalone=pd.read_csv(q_file_name_standalone)
y_file_standalone=pd.read_csv(y_file_name_standalone)
s_file_standalone=pd.read_csv(s_file_name_standalone)

# %%
def Diff(li1, li2): 
    li_dif = [i for i in li1 + li2 if i not in li1 or i not in li2] 
    return li_dif 
z_symbol=z_file_consolidated['Ticker'].tolist()
missing_symbol=Diff(z_symbol,symbol_list)
z_file_consolidated=z_file_consolidated.append(z_file_standalone[z_file_standalone['Ticker'].isin(missing_symbol)])
q_symbol=q_file_consolidated['Ticker'].tolist()
missing_symbol=Diff(q_symbol,symbol_list)
q_file_consolidated=q_file_consolidated.append(q_file_standalone[q_file_standalone['Ticker'].isin(missing_symbol)])
#q_file_consolidated
y_symbol=y_file_consolidated['Ticker'].tolist()
missing_symbol=Diff(y_symbol,symbol_list)
y_file_consolidated=y_file_consolidated.append(y_file_standalone[y_file_standalone['Ticker'].isin(missing_symbol)])
#y_file_consolidated
s_symbol=y_file_consolidated['Ticker'].tolist()
missing_symbol=Diff(s_symbol,symbol_list)
s_file_consolidated=y_file_consolidated.append(s_file_standalone[s_file_standalone['Ticker'].isin(missing_symbol)])
#s_file_consolidated

# %%
z_file_consolidated.to_csv(z_file_name_consolidated)
y_file_consolidated.to_csv(y_file_name_consolidated)
q_file_consolidated.to_csv(q_file_name_consolidated)
s_file_consolidated.to_csv(s_file_name_consolidated)

# %%
z_file_consolidated[z_file_consolidated['Name']==z_file_consolidated['Company_Name']].to_csv('data/Peer_Ticker_nifty500_consoldiated_cleaned.csv')

# %%
z_file_standalone[z_file_standalone['Name']==z_file_standalone['Company_Name']].to_csv('data/Peer_Ticker_nifty500_stand_cleaned.csv')

# %% [markdown]
# # Save Cookie fo

# %%
def save_cookie(driver, path):
    with open(path, 'wb') as filehandler:
        pickle.dump(driver.get_cookies(), filehandler)

def load_cookie(driver, path):
     with open(path, 'rb') as cookiesfile:
         cookies = pickle.load(cookiesfile)
         for cookie in cookies:
             driver.add_cookie(cookie)

# %%
driver = selenium.webdriver.Chrome('C:\\Users\\sashhar\\Desktop\\Quantopian\\driver\\chromedriver.exe')
driver.get("https://www.screener.in/login/")

# %%
pickle.dump( driver.get_cookies() , open("sabeeh1983_cookie.pkl","wb"))
