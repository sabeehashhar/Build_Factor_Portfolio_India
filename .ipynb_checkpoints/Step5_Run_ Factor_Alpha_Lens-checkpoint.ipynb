# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import warnings
from alphalens import plotting
from alphalens import performance as perf
from alphalens import utils
from scipy import stats
import statsmodels.api as sm

# %%
#***********************This Section is to read from saved file and index*****************
concat_df=pd.read_csv('data/Data_Y_nifty1000.csv')
concat_df=concat_df[concat_df['Capitalization'] !='MICROCAP']
screen_data=pd.read_csv('data/Peer_Ticker_nifty1000_stand_cleaned.csv')
screen_1=screen_data[screen_data['Debt / Eq'] < 0.33]
screen_2=screen_1[screen_1['Prom. Hold.  %'] > 20]
#screen_3=screen_2[screen_2['ROE  %'] > 15]
#screen_3=screen_3[screen_3['ROA 12M  %'] > 10]
screen_4=screen_2[screen_2['CMP  Rs.'] < 5000]
#screen_4=screen_4[screen_4['CMP  Rs.'] > 50]
screen_4=screen_4['Ticker'].unique().tolist()
len(screen_4)
concat_df=concat_df[concat_df['Symbol'].isin(screen_4)]

# %%
concat_df.groupby('Capitalization')['Symbol'].apply(lambda x:len(x.unique().tolist()))
# Out:
# Capitalization
# LARGE        43
# MIDCAP       56
# SMALLCAP    112
# Name: Symbol, dtype: int64

# %%
column_list=['Share_Turnover','Momentum', 'Mom_Sharpe', 'Mom_Gain_Loss', 'Mom_Slope',
       'Liquidity', 'Volatility', 'CAPM_Beta','CAPM_Alpha', 'Sales_Growth',
       'OPM_Growth', 'EPS_Growth', 'EPS', 'E/P', 'PEG','Size_Factor', 'StDev']
for column in column_list:
    concat_df[concat_df[column]==""] = np.NaN
    concat_df[column]=concat_df.groupby('Symbol')[column].fillna(method='bfill')
    concat_df[column]=concat_df.groupby('Symbol')[column].fillna(method='ffill')

# %%
column_list=['Share_Turnover','Return', 'Momentum', 'Mom_Sharpe', 'Mom_Gain_Loss', 'Mom_Slope',
       'Liquidity', 'Volatility', 'CAPM_Beta','CAPM_Alpha', 'Sales_Growth',
       'OPM_Growth', 'EPS_Growth', 'EPS', 'E/P', 'PEG','Size_Factor', 'StDev']
for column in column_list:
    #concat_df[column]=concat_df.groupby('Date')[column].apply(lambda x:np.where(x > x.quantile(0.99),x.quantile(0.99), x))
    #concat_df[column]=concat_df.groupby('Date')[column].apply(lambda x:np.where(x > x.quantile(0.01),x.quantile(0.01), x))
    concat_df[column]=np.where(concat_df[column] > concat_df[column].quantile(0.99),concat_df[column].quantile(0.99), concat_df[column])
    concat_df[column]=np.where(concat_df[column] < concat_df[column].quantile(0.01),concat_df[column].quantile(0.01), concat_df[column])

# %%
column_list=['Share_Turnover','Momentum', 'Mom_Sharpe', 'Mom_Gain_Loss', 'Mom_Slope',
       'Liquidity', 'Volatility', 'CAPM_Beta','CAPM_Alpha', 'Sales_Growth',
       'OPM_Growth', 'EPS_Growth', 'EPS', 'E/P', 'PEG','Size_Factor', 'StDev']
for column in column_list:
    concat_df[column]=concat_df.groupby('Date')[column].rank(ascending=1)

# %%
concat_df['MomSharpe_Size_EP']=concat_df['Mom_Sharpe']+concat_df['Size_Factor']+concat_df['E/P']
concat_df['Mom_Size']=concat_df['Momentum']+concat_df['Size_Factor']
concat_df['MomSharpe_Size']=concat_df['Mom_Sharpe']+concat_df['Size_Factor']
concat_df['Mom_Std_Sales']=concat_df['Momentum']+concat_df['StDev']+concat_df['Sales_Growth']
concat_df['Mom_EP']=concat_df['Momentum']+concat_df['E/P']
concat_df['Size_EP']=concat_df['Size_Factor']+concat_df['E/P']
concat_df['Vol_Size_EP']=concat_df['Volatility']+concat_df['Size_Factor']+concat_df['E/P']
concat_df['Mom_Size_Sales']=concat_df['Momentum']+concat_df['Size_Factor']+concat_df['Sales_Growth']
concat_df['Mom_Size_Sales_Std']=concat_df['Momentum']+concat_df['Size_Factor']+concat_df['Sales_Growth']+concat_df['StDev']
concat_df['Mom_Size_Std']=concat_df['Momentum']+concat_df['Size_Factor']+concat_df['StDev']
concat_df['Size_Std']=concat_df['Size_Factor']+concat_df['StDev']
concat_df['Mom_Std']=concat_df['Momentum']+concat_df['StDev']
concat_df['Size_Sales_EP']=concat_df['Size_Factor']+concat_df['Sales_Growth']+concat_df['E/P']

# %%
concat_df.set_index(pd.DatetimeIndex(concat_df['Date']), append=False, inplace=True)
concat_df.index.tz_localize('UTC')
concat_df.set_index(['Symbol'], append=True, inplace=True)
concat_df=concat_df.reorder_levels(['Date', 'Symbol'])
concat_df.sort_index(inplace=True)
concat_df=concat_df.groupby(level=concat_df.index.names).last()
#concat_df.drop(['Date'])
concat_df.columns
concat_df=concat_df.drop(['Unnamed: 0', 'Date'], axis=1)
concat_df.columns
# Out:
# Index(['Company Name', 'Sector', 'Industry', 'Capitalization', 'Unnamed: 0.1',
#        'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Share_Turnover',
#        'Return', 'Momentum', 'Mom_Sharpe', 'Mom_Gain_Loss', 'Mom_Slope',
#        'StDev', 'Liquidity', 'Volatility', 'NSE500', 'CAPM_Beta', 'CAPM_Alpha',
#        'Sec_Rank', 'Sector_Return', 'Sales', 'OPM', 'NetProfit', 'EPSinRs',
#        'DividendPayout', 'OtherLiabilities', 'Open_Shares', 'Sales_Growth',
#        'EPS_Growth', 'OPM_Growth', 'ROE', 'Leverage', 'BVPS', 'Sale_per_share',
#        'EPS in Rs', 'EPS', 'E/P', 'Sales/Price', 'BV/Price', 'PEG',
#        'Div/Price', 'Size_Factor', 'Quality', 'Value', 'MomSharpe_Size_EP',
#        'Mom_Size', 'MomSharpe_Size', 'Mom_Std_Sales', 'Mom_EP', 'Size_EP',
#        'Vol_Size_EP', 'Mom_Size_Sales', 'Mom_Size_Sales_Std', 'Mom_Size_Std',
#        'Size_Std', 'Mom_Std', 'Size_Sales_EP'],
#       dtype='object')

# %%
concat_df.head()
# Out:
#                                       Company Name           Sector  \
# Date       Symbol
# 2010-01-04 ACC                            ACC Ltd.  Basic Materials
#            AEGISCHEM          Aegis Logistics Ltd.           Energy
#            AIAENG             AIA Engineering Ltd.      Industrials
#            AJANTPHARM  Ajanta Pharmaceuticals Ltd.       Healthcare
#            AKZOINDIA         Akzo Nobel India Ltd.  Basic Materials
#
#                                                        Industry  \
# Date       Symbol
# 2010-01-04 ACC                               Building Materials
#            AEGISCHEM                        Oil & Gas Midstream
#            AIAENG                Specialty Industrial Machinery
#            AJANTPHARM  Drug Manufacturers - Specialty & Generic
#            AKZOINDIA                        Specialty Chemicals
#
#                       Capitalization  Unnamed: 0.1      Open     High  \
# Date       Symbol
# 2010-01-04 ACC                 LARGE      263049.0  870.0000  920.000
#            AEGISCHEM        SMALLCAP      263057.0   12.3000   13.548
#            AIAENG             MIDCAP      263060.0  374.0000  382.000
#            AJANTPHARM         MIDCAP      263061.0   15.9733   16.000
#            AKZOINDIA          MIDCAP      263063.0  650.0000  665.000
#
#                               Low       Close   Adj Close  ...  Mom_Std_Sales  \
# Date       Symbol                                          ...
# 2010-01-04 ACC         870.000000  913.599976  733.765442  ...      35.971679
#            AEGISCHEM    12.141000   13.347000    3.752670  ...      22.962514
#            AIAENG      362.649994  372.750000  337.829895  ...      31.748371
#            AJANTPHARM   15.533300   15.640000   10.150526  ...      28.726476
#            AKZOINDIA   646.000000  654.700012  548.785828  ...      63.404580
#
#                          Mom_EP   Size_EP  Vol_Size_EP  Mom_Size_Sales  \
# Date       Symbol
# 2010-01-04 ACC         0.503271 -9.449305    -9.003274       -9.146081
#            AEGISCHEM   1.221987 -4.440486    -3.724632       -4.107623
#            AIAENG      0.862839 -8.032096    -7.511467       -7.375227
#            AJANTPHARM  0.908099 -4.190053    -3.623115       -3.722853
#            AKZOINDIA   0.356675      -inf         -inf            -inf
#
#                        Mom_Size_Sales_Std  Mom_Size_Std   Size_Std    Mom_Std  \
# Date       Symbol
# 2010-01-04 ACC                  26.441068     26.478501  26.056537  36.009113
#            AEGISCHEM            18.191596     18.419857  17.528301  23.190774
#            AIAENG               23.677824     23.806891  22.982504  31.877438
#            AJANTPHARM           24.217228     24.019735  23.430832  28.528983
#            AKZOINDIA                 -inf          -inf       -inf  63.357522
#
#                        Size_Sales_EP
# Date       Symbol
# 2010-01-04 ACC             -9.486739
#            AEGISCHEM       -4.668747
#            AIAENG          -8.161163
#            AJANTPHARM      -3.992561
#            AKZOINDIA            -inf
#
# [5 rows x 62 columns]

# %%
def get_factor_information(factor_data, factor_name="factor_name"):
    ic_data=perf.factor_information_coefficient(merged_data, group_adjust=False,by_group=False)
    ic_summary_table = pd.DataFrame()
    ic_summary_table["IC Mean"] = ic_data.mean()
    ic_summary_table["IC Std."] = ic_data.std()
    ic_summary_table["Risk-Adjusted IC"] = ic_data.mean() / ic_data.std()
    t_stat, p_value = stats.ttest_1samp(ic_data, 0)
    ic_summary_table["t-stat(IC)"] = t_stat
    ic_summary_table["p-value(IC)"] = p_value
    ic_summary_table["IC Skew"] = stats.skew(ic_data)
    ic_summary_table["IC Kurtosis"] = stats.kurtosis(ic_data)
    ic_summary_table=ic_summary_table.T
    ic_summary_table["Factor_Data"] = factor_name
    ic_summary_table["Attribute"]="Factor_Information"
    return ic_summary_table

# %%
def get_factor_returns(factor_data,factor_name="factor_name", long_short=True, group_neutral=False, by_group=False):  
    factor_returns = perf.factor_returns(factor_data, long_short, group_neutral)
    mean_quant_ret, std_quantile = perf.mean_return_by_quantile(factor_data,by_group=False,demeaned=long_short,group_adjust=group_neutral,)
    mean_quant_rateret = mean_quant_ret.apply(utils.rate_of_return, axis=0, base_period=mean_quant_ret.columns[0])
    mean_quant_ret_bydate, std_quant_daily = perf.mean_return_by_quantile(factor_data,by_date=True,by_group=False,demeaned=long_short,group_adjust=group_neutral,)
    mean_quant_rateret_bydate = mean_quant_ret_bydate.apply(utils.rate_of_return,axis=0,base_period=mean_quant_ret_bydate.columns[0],)
    compstd_quant_daily = std_quant_daily.apply(utils.std_conversion, axis=0, base_period=std_quant_daily.columns[0])
    alpha_beta = perf.factor_alpha_beta(factor_data, factor_returns, long_short, group_neutral)
    mean_ret_spread_quant, std_spread_quant = perf.compute_mean_returns_spread(mean_quant_rateret_bydate,factor_data["factor_quantile"].max(),factor_data["factor_quantile"].min(),std_err=compstd_quant_daily,)
    returns_table = pd.DataFrame()
    returns_table = returns_table.append(alpha_beta)
    returns_table.loc["Mean Period Wise Return Top Quantile (bps)"] = mean_quant_rateret.iloc[-1] * DECIMAL_TO_BPS
    returns_table.loc["Mean Period Wise Return Bottom Quantile (bps)"] = mean_quant_rateret.iloc[0] * DECIMAL_TO_BPS
    returns_table.loc["Mean Period Wise Spread (bps)"] = mean_ret_spread_quant.mean() * DECIMAL_TO_BPS
    #returns_table=returns_table.T
    returns_table["Factor_Data"]=factor_name
    returns_table["Attribute"]="Factor_Returns"
    return returns_table

# %%
DECIMAL_TO_BPS = 10000

# %%
def get_factor_turnover(factor_data,factor_name="factor_name", turnover_periods=None):  
    if turnover_periods is None:
        input_periods = utils.get_forward_returns_columns(factor_data.columns, require_exact_day_multiple=True,).tolist()
        turnover_periods = utils.timedelta_strings_to_integers(input_periods)
    else:
        turnover_periods = utils.timedelta_strings_to_integers(turnover_periods,)
    quantile_factor = factor_data["factor_quantile"]

    quantile_turnover = {
        p: pd.concat(
            [
                perf.quantile_turnover(quantile_factor, q, p)
                for q in quantile_factor.sort_values().unique().tolist()
            ],
            axis=1,
        )
        for p in turnover_periods
    }
    autocorrelation = pd.concat(
        [
            perf.factor_rank_autocorrelation(factor_data, period)
            for period in turnover_periods
        ],
        axis=1,
    )
    turnover_table = pd.DataFrame()
    for period in sorted(quantile_turnover.keys()):
        for quantile, p_data in quantile_turnover[period].iteritems():
            turnover_table.loc["Quantile {} Mean Turnover ".format(quantile),
                               "{}D".format(period)] = p_data.mean()
    auto_corr = pd.DataFrame()
    for period, p_data in autocorrelation.iteritems():
        auto_corr.loc["Mean Factor Rank Autocorrelation",
                      "{}D".format(period)] = p_data.mean()
    #auto_corr.append(turnover_table)
    #auto_corr=auto_corr.T
    #turnover_table=turnover_table.T
    auto_corr["Factor_Data"]=factor_name
    auto_corr["Attribute"]="Factor_Turnover"
    turnover_table["Factor_Data"]=factor_name
    turnover_table["Attribute"]="Factor_Turnover"
    return auto_corr, turnover_table

# %%
concat_df.columns
# Out:
# Index(['Company Name', 'Sector', 'Industry', 'Capitalization', 'Unnamed: 0.1',
#        'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Share_Turnover',
#        'Return', 'Momentum', 'Mom_Sharpe', 'Mom_Gain_Loss', 'Mom_Slope',
#        'StDev', 'Liquidity', 'Volatility', 'NSE500', 'CAPM_Beta', 'CAPM_Alpha',
#        'Sec_Rank', 'Sector_Return', 'Sales', 'OPM', 'NetProfit', 'EPSinRs',
#        'DividendPayout', 'OtherLiabilities', 'Open_Shares', 'Sales_Growth',
#        'EPS_Growth', 'OPM_Growth', 'ROE', 'Leverage', 'BVPS', 'Sale_per_share',
#        'EPS in Rs', 'EPS', 'E/P', 'Sales/Price', 'BV/Price', 'PEG',
#        'Div/Price', 'Size_Factor', 'Quality', 'Value', 'MomSharpe_Size_EP',
#        'Mom_Size', 'MomSharpe_Size', 'Mom_Std_Sales', 'Mom_EP', 'Size_EP',
#        'Vol_Size_EP', 'Mom_Size_Sales', 'Mom_Size_Sales_Std', 'Mom_Size_Std',
#        'Size_Std', 'Mom_Std', 'Size_Sales_EP'],
#       dtype='object')

# %%
#factor_list= concat_df.columns.tolist()
#del factor_list[0:10]
factor_list=['Momentum', 'Mom_Sharpe', 'Mom_Slope',
       'StDev','ROE', 'E/P', 'Sales/Price', 'BV/Price',
       'Size_Factor', 'Quality', 'Value', 'MomSharpe_Size_EP','Vol_Size_EP',
       'Mom_Size','Mom_EP', 'Size_EP', 'Mom_Size_Std', 'Size_Std']
#factor_list.remove('Return_1','Return_2', 'Return_3', 'Return_4', 'Return_5')
#factor_list.remove('Return')
#factor_list=factor_list[1:7]
#factor_list=[ 'Prob_10_0.02', 'Prob_10_0.05', 'Prob_10_0.1', 'Prob_10_0.15', 'Mom_Size', 'Mom_EP', 'Mom_Size_Sales',
       #'Size_Sales', 'Mom_Size_Sales_Std', 'Size_Sales_Std', 'Mom_Size_Std',
       #'Mom_Size_Std_Vol', 'Size_Std', 'Mom_Std', 'Mom_Size_OPM',
       #'Mom_Size_Sales_EP', 'Size_Sales_EP', 'Mom_Size_EPS', 'Mom_Size_EP',
       #'Mom_Vol', 'Mom_Vol_StDev', 'Vol_StDev']
print(factor_list)
# Out:
# ['Momentum', 'Mom_Sharpe', 'Mom_Slope', 'StDev', 'ROE', 'E/P', 'Sales/Price', 'BV/Price', 'Size_Factor', 'Quality', 'Value', 'MomSharpe_Size_EP', 'Vol_Size_EP', 'Mom_Size', 'Mom_EP', 'Size_EP', 'Mom_Size_Std', 'Size_Std']

# %%
price_data=pd.DataFrame(concat_df['Adj Close']).stack().unstack(level=1)
price_data.head()
price_data.index.name=None
price_data.index = price_data.index.droplevel(1)
price_data.head()
from alphalens.utils import get_clean_factor_and_forward_returns
#longest_look_forward_period = 90 # week = 5, month = 21, quarter = 63, year = 252
#range_step = 5

# %%
combined_df=pd.DataFrame()
#factor_information=pd.DataFrame()
count = 1 
for factor_name in factor_list:
    factor_data=pd.DataFrame(concat_df[factor_name])
    factor_data.index.name = ""
    merged_data = get_clean_factor_and_forward_returns(factor=factor_data,prices=price_data,periods = (5,10,20,66,130,250),max_loss=0.45)
    print("Running Alphalens for Factor: ",count, factor_name)
    factor_information=get_factor_information(merged_data,factor_name) 
    #print(factor_information.head())
    combined_df=combined_df.append(factor_information)
    #print("Running Factor Returns for Factor: ", factor_name)
    factor_returns=get_factor_returns(merged_data,factor_name)
    #print(factor_returns.head())
    combined_df=combined_df.append(factor_returns)
    #print("Running Factor Turnover for Factor: ", factor_name)
    factor_auto_corr, factor_turnover_table=get_factor_turnover(merged_data,factor_name)
    #print(factor_auto_corr.head())
    #print(factor_turnover_table.head())
    combined_df=combined_df.append(factor_auto_corr)
    combined_df=combined_df.append(factor_turnover_table)
    count=count + 1
combined_df.to_csv('Combined_Alpha_Factor.csv')
#factor_information.to_csv('Factor_Information.csv')
# Out:
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  1 Momentum
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  2 Mom_Sharpe
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  3 Mom_Slope
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  4 StDev
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  5 ROE
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  6 E/P
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  7 Sales/Price
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  8 BV/Price
# Dropped 12.5% entries from factor data: 12.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  9 Size_Factor
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  10 Quality
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  11 Value
# Dropped 12.5% entries from factor data: 12.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  12 MomSharpe_Size_EP
# Dropped 12.5% entries from factor data: 12.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  13 Vol_Size_EP
# Dropped 12.5% entries from factor data: 12.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  14 Mom_Size
# Dropped 11.0% entries from factor data: 11.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  15 Mom_EP
# Dropped 12.5% entries from factor data: 12.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  16 Size_EP
# Dropped 12.5% entries from factor data: 12.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  17 Mom_Size_Std
# Dropped 12.5% entries from factor data: 12.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
# Running Alphalens for Factor:  18 Size_Std

# %%
import scipy.cluster.hierarchy as spc
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt

def plot_corr(df,size=10):
    # Compute the correlation matrix for the received dataframe
    dist = pdist(df.corr().values)
    linkage = spc.linkage(dist, method='complete')
    idx = spc.fcluster(linkage, 0.5 * dist.min(), 'distance')
    columns = [df.columns.tolist()[i] for i in list((np.argsort(idx)))]
    #corr = df.reindex_axis(columns, axis=1).corr()
    corr = df.corr()
    
    # Plot the correlation matrix
    fig, ax = plt.subplots(figsize=(size, size))
    cax = ax.matshow(corr, cmap='RdYlGn')
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90);
    plt.yticks(range(len(corr.columns)), corr.columns);
    
    # Add the colorbar legend
    cbar = fig.colorbar(cax, ticks=[-1, 0, 1], aspect=40, shrink=.8)

# %%
factor_return=pd.read_csv('data/Factor_Return_Q.csv')
#factor_return=factor_return.set_index('Date')
factor_return.columns
# Out:
# Index(['Date', 'Plot_Momentum', 'Plot_Mom_Sharpe', 'Plot_Mom_Slope',
#        'Plot_StDev', 'Plot_Sector_Return', 'Plot_Sales_Growth',
#        'Plot_OPM_Growth', 'Plot_EPS_Growth', 'Plot_EPS', 'Plot_E/P',
#        'Plot_PEG', 'Plot_S/P', 'Plot_Size_Factor', 'Plot_Mom_Size',
#        'Plot_Mom_Val', 'Plot_Vol_EP_Size', 'Plot_Mom_Sharpe_EP_Size_Factor',
#        'Plot_EP_Size', 'Plot_Mom_Std', 'Plot_Mom_Growth',
#        'Plot_Mom_Size_Sales', 'Plot_Mom_M_Size_Sales', 'Plot_Mom_M_EPS',
#        'Plot_Mom_Sharpe_Size_Sales', 'Plot_Mom_Std_Sales',
#        'Plot_Mom_Size_Sales_Std', 'Plot_Mom_Size_Std',
#        'Plot_Mom_Size_Sales_EP', 'Plot_Mom_Size_EPS', 'Plot_Mom_Size_EP',
#        'Plot_Mom_Vol_StDev'],
#       dtype='object')

# %%
f1=factor_return[['Plot_Momentum', 'Plot_Mom_Sharpe', 'Plot_Mom_Slope',
       'Plot_StDev', 'Plot_Sector_Return', 'Plot_Sales_Growth',
       'Plot_OPM_Growth', 'Plot_EPS_Growth', 'Plot_EPS', 'Plot_E/P',
       'Plot_PEG', 'Plot_S/P', 'Plot_Size_Factor', 'Plot_Mom_Size',
       'Plot_Mom_Val', 'Plot_Vol_EP_Size', 'Plot_Mom_Sharpe_EP_Size_Factor',
       'Plot_EP_Size', 'Plot_Mom_Std', 'Plot_Mom_Growth',
       'Plot_Mom_Size_Sales', 'Plot_Mom_M_Size_Sales', 'Plot_Mom_M_EPS',
       'Plot_Mom_Sharpe_Size_Sales', 'Plot_Mom_Std_Sales',
       'Plot_Mom_Size_Sales_Std', 'Plot_Mom_Size_Std',
       'Plot_Mom_Size_Sales_EP', 'Plot_Mom_Size_EPS', 'Plot_Mom_Size_EP',
       'Plot_Mom_Vol_StDev']]

# %%
plot_corr(factor_return)

# %%
factor_return.corr()
# Out:
#                                 Plot_Momentum  Plot_Mom_Sharpe  \
# Plot_Momentum                        1.000000         0.834974
# Plot_Mom_Sharpe                      0.834974         1.000000
# Plot_Mom_Slope                       0.848141         0.910737
# Plot_StDev                           0.815486         0.689337
# Plot_Sector_Return                   0.744310         0.970850
# Plot_Sales_Growth                    0.875669         0.586943
# Plot_OPM_Growth                      0.747116         0.375953
# Plot_EPS_Growth                      0.713482         0.373880
# Plot_EPS                             0.705451         0.348400
# Plot_E/P                             0.690801         0.312926
# Plot_PEG                             0.851868         0.610847
# Plot_S/P                            -0.448331        -0.823934
# Plot_Size_Factor                     0.847093         0.964747
# Plot_Mom_Size                        0.868946         0.976696
# Plot_Mom_Val                         0.937089         0.897934
# Plot_Vol_EP_Size                     0.863305         0.955086
# Plot_Mom_Sharpe_EP_Size_Factor       0.854650         0.980884
# Plot_EP_Size                         0.828403         0.944654
# Plot_Mom_Std                         0.876406         0.871889
# Plot_Mom_Growth                      0.797852         0.932675
# Plot_Mom_Size_Sales                  0.831209         0.919818
# Plot_Mom_M_Size_Sales                0.836898         0.939655
# Plot_Mom_M_EPS                       0.930841         0.891020
# Plot_Mom_Sharpe_Size_Sales           0.799331         0.970944
# Plot_Mom_Std_Sales                   0.812372         0.960339
# Plot_Mom_Size_Sales_Std              0.856605         0.958708
# Plot_Mom_Size_Std                    0.933976         0.879472
# Plot_Mom_Size_Sales_EP               0.829950         0.967051
# Plot_Mom_Size_EPS                    0.839588         0.985472
# Plot_Mom_Size_EP                     0.883507         0.969399
# Plot_Mom_Vol_StDev                   0.969850         0.926502
#
#                                 Plot_Mom_Slope  Plot_StDev  \
# Plot_Momentum                         0.848141    0.815486
# Plot_Mom_Sharpe                       0.910737    0.689337
# Plot_Mom_Slope                        1.000000    0.839022
# Plot_StDev                            0.839022    1.000000
# Plot_Sector_Return                    0.840106    0.594610
# Plot_Sales_Growth                     0.646323    0.705113
# Plot_OPM_Growth                       0.480306    0.677082
# Plot_EPS_Growth                       0.393066    0.501626
# Plot_EPS                              0.315090    0.584857
# Plot_E/P                              0.412414    0.682036
# Plot_PEG                              0.546918    0.674892
# Plot_S/P                             -0.607528   -0.235101
# Plot_Size_Factor                      0.938610    0.784094
# Plot_Mom_Size                         0.888244    0.735032
# Plot_Mom_Val                          0.879428    0.844829
# Plot_Vol_EP_Size                      0.900735    0.790470
# Plot_Mom_Sharpe_EP_Size_Factor        0.887239    0.723716
# Plot_EP_Size                          0.935063    0.825570
# Plot_Mom_Std                          0.933120    0.888544
# Plot_Mom_Growth                       0.948747    0.723076
# Plot_Mom_Size_Sales                   0.966985    0.823084
# Plot_Mom_M_Size_Sales                 0.948337    0.786486
# Plot_Mom_M_EPS                        0.865299    0.837929
# Plot_Mom_Sharpe_Size_Sales            0.947669    0.751021
# Plot_Mom_Std_Sales                    0.946427    0.755261
# Plot_Mom_Size_Sales_Std               0.949955    0.787075
# Plot_Mom_Size_Std                     0.907004    0.883223
# Plot_Mom_Size_Sales_EP                0.944669    0.775580
# Plot_Mom_Size_EPS                     0.909198    0.722464
# Plot_Mom_Size_EP                      0.918432    0.785255
# Plot_Mom_Vol_StDev                    0.889874    0.785217
#
#                                 Plot_Sector_Return  Plot_Sales_Growth  \
# Plot_Momentum                             0.744310           0.875669
# Plot_Mom_Sharpe                           0.970850           0.586943
# Plot_Mom_Slope                            0.840106           0.646323
# Plot_StDev                                0.594610           0.705113
# Plot_Sector_Return                        1.000000           0.498191
# Plot_Sales_Growth                         0.498191           1.000000
# Plot_OPM_Growth                           0.288892           0.892791
# Plot_EPS_Growth                           0.335293           0.891038
# Plot_EPS                                  0.275305           0.681676
# Plot_E/P                                  0.194357           0.730796
# Plot_PEG                                  0.584899           0.828257
# Plot_S/P                                 -0.872101          -0.197753
# Plot_Size_Factor                          0.937916           0.653507
# Plot_Mom_Size                             0.962207           0.649239
# Plot_Mom_Val                              0.822052           0.721969
# Plot_Vol_EP_Size                          0.932046           0.644532
# Plot_Mom_Sharpe_EP_Size_Factor            0.968774           0.618329
# Plot_EP_Size                              0.901514           0.612506
# Plot_Mom_Std                              0.777372           0.696658
# Plot_Mom_Growth                           0.895966           0.653317
# Plot_Mom_Size_Sales                       0.873892           0.657309
# Plot_Mom_M_Size_Sales                     0.916389           0.665533
# Plot_Mom_M_EPS                            0.813500           0.722135
# Plot_Mom_Sharpe_Size_Sales                0.944245           0.562690
# Plot_Mom_Std_Sales                        0.943702           0.623707
# Plot_Mom_Size_Sales_Std                   0.927122           0.687780
# Plot_Mom_Size_Std                         0.802457           0.801426
# Plot_Mom_Size_Sales_EP                    0.939512           0.608402
# Plot_Mom_Size_EPS                         0.973722           0.621128
# Plot_Mom_Size_EP                          0.941175           0.677163
# Plot_Mom_Vol_StDev                        0.847701           0.801372
#
#                                 Plot_OPM_Growth  Plot_EPS_Growth  Plot_EPS  \
# Plot_Momentum                          0.747116         0.713482  0.705451
# Plot_Mom_Sharpe                        0.375953         0.373880  0.348400
# Plot_Mom_Slope                         0.480306         0.393066  0.315090
# Plot_StDev                             0.677082         0.501626  0.584857
# Plot_Sector_Return                     0.288892         0.335293  0.275305
# Plot_Sales_Growth                      0.892791         0.891038  0.681676
# Plot_OPM_Growth                        1.000000         0.922127  0.721439
# Plot_EPS_Growth                        0.922127         1.000000  0.666061
# Plot_EPS                               0.721439         0.666061  1.000000
# Plot_E/P                               0.829851         0.687101  0.861744
# Plot_PEG                               0.812222         0.842388  0.859702
# Plot_S/P                               0.104776         0.003530  0.028003
# Plot_Size_Factor                       0.492709         0.459686  0.369966
# Plot_Mom_Size                          0.482675         0.481199  0.462306
# Plot_Mom_Val                           0.594806         0.518587  0.659419
# Plot_Vol_EP_Size                       0.528284         0.480217  0.476310
# Plot_Mom_Sharpe_EP_Size_Factor         0.448743         0.447914  0.443246
# Plot_EP_Size                           0.492007         0.401930  0.396005
# Plot_Mom_Std                           0.530814         0.419144  0.500836
# Plot_Mom_Growth                        0.445438         0.427300  0.200233
# Plot_Mom_Size_Sales                    0.519240         0.441901  0.303938
# Plot_Mom_M_Size_Sales                  0.515210         0.479458  0.315057
# Plot_Mom_M_EPS                         0.598128         0.518703  0.669955
# Plot_Mom_Sharpe_Size_Sales             0.390611         0.341249  0.278156
# Plot_Mom_Std_Sales                     0.427041         0.414154  0.283325
# Plot_Mom_Size_Sales_Std                0.514019         0.488083  0.344731
# Plot_Mom_Size_Std                      0.657183         0.586173  0.585431
# Plot_Mom_Size_Sales_EP                 0.458361         0.412624  0.332411
# Plot_Mom_Size_EPS                      0.450300         0.445286  0.373988
# Plot_Mom_Size_EP                       0.521205         0.493792  0.458959
# Plot_Mom_Vol_StDev                     0.621404         0.591217  0.608180
#
#                                 Plot_E/P  ...  Plot_Mom_M_Size_Sales  \
# Plot_Momentum                   0.690801  ...               0.836898
# Plot_Mom_Sharpe                 0.312926  ...               0.939655
# Plot_Mom_Slope                  0.412414  ...               0.948337
# Plot_StDev                      0.682036  ...               0.786486
# Plot_Sector_Return              0.194357  ...               0.916389
# Plot_Sales_Growth               0.730796  ...               0.665533
# Plot_OPM_Growth                 0.829851  ...               0.515210
# Plot_EPS_Growth                 0.687101  ...               0.479458
# Plot_EPS                        0.861744  ...               0.315057
# Plot_E/P                        1.000000  ...               0.366284
# Plot_PEG                        0.742946  ...               0.627355
# Plot_S/P                        0.181943  ...              -0.675832
# Plot_Size_Factor                0.412499  ...               0.976822
# Plot_Mom_Size                   0.409634  ...               0.950458
# Plot_Mom_Val                    0.649809  ...               0.870388
# Plot_Vol_EP_Size                0.476963  ...               0.956083
# Plot_Mom_Sharpe_EP_Size_Factor  0.395715  ...               0.946271
# Plot_EP_Size                    0.463000  ...               0.959958
# Plot_Mom_Std                    0.529355  ...               0.864495
# Plot_Mom_Growth                 0.272798  ...               0.973105
# Plot_Mom_Size_Sales             0.395091  ...               0.990864
# Plot_Mom_M_Size_Sales           0.366284  ...               1.000000
# Plot_Mom_M_EPS                  0.663022  ...               0.860114
# Plot_Mom_Sharpe_Size_Sales      0.311879  ...               0.978138
# Plot_Mom_Std_Sales              0.304139  ...               0.971458
# Plot_Mom_Size_Sales_Std         0.376976  ...               0.987927
# Plot_Mom_Size_Std               0.594298  ...               0.897567
# Plot_Mom_Size_Sales_EP          0.372727  ...               0.985012
# Plot_Mom_Size_EPS               0.356535  ...               0.969004
# Plot_Mom_Size_EP                0.442234  ...               0.970249
# Plot_Mom_Vol_StDev              0.575824  ...               0.888735
#
#                                 Plot_Mom_M_EPS  Plot_Mom_Sharpe_Size_Sales  \
# Plot_Momentum                         0.930841                    0.799331
# Plot_Mom_Sharpe                       0.891020                    0.970944
# Plot_Mom_Slope                        0.865299                    0.947669
# Plot_StDev                            0.837929                    0.751021
# Plot_Sector_Return                    0.813500                    0.944245
# Plot_Sales_Growth                     0.722135                    0.562690
# Plot_OPM_Growth                       0.598128                    0.390611
# Plot_EPS_Growth                       0.518703                    0.341249
# Plot_EPS                              0.669955                    0.278156
# Plot_E/P                              0.663022                    0.311879
# Plot_PEG                              0.787245                    0.562309
# Plot_S/P                             -0.543255                   -0.754017
# Plot_Size_Factor                      0.893999                    0.980777
# Plot_Mom_Size                         0.923718                    0.958950
# Plot_Mom_Val                          0.998604                    0.880915
# Plot_Vol_EP_Size                      0.927284                    0.959514
# Plot_Mom_Sharpe_EP_Size_Factor        0.922751                    0.962826
# Plot_EP_Size                          0.915064                    0.973811
# Plot_Mom_Std                          0.901280                    0.876811
# Plot_Mom_Growth                       0.803467                    0.958838
# Plot_Mom_Size_Sales                   0.863196                    0.974905
# Plot_Mom_M_Size_Sales                 0.860114                    0.978138
# Plot_Mom_M_EPS                        1.000000                    0.872209
# Plot_Mom_Sharpe_Size_Sales            0.872209                    1.000000
# Plot_Mom_Std_Sales                    0.848798                    0.973797
# Plot_Mom_Size_Sales_Std               0.877762                    0.977347
# Plot_Mom_Size_Std                     0.932330                    0.881269
# Plot_Mom_Size_Sales_EP                0.895685                    0.991743
# Plot_Mom_Size_EPS                     0.894588                    0.979897
# Plot_Mom_Size_EP                      0.935831                    0.967177
# Plot_Mom_Vol_StDev                    0.950909                    0.885194
#
#                                 Plot_Mom_Std_Sales  Plot_Mom_Size_Sales_Std  \
# Plot_Momentum                             0.812372                 0.856605
# Plot_Mom_Sharpe                           0.960339                 0.958708
# Plot_Mom_Slope                            0.946427                 0.949955
# Plot_StDev                                0.755261                 0.787075
# Plot_Sector_Return                        0.943702                 0.927122
# Plot_Sales_Growth                         0.623707                 0.687780
# Plot_OPM_Growth                           0.427041                 0.514019
# Plot_EPS_Growth                           0.414154                 0.488083
# Plot_EPS                                  0.283325                 0.344731
# Plot_E/P                                  0.304139                 0.376976
# Plot_PEG                                  0.593111                 0.645533
# Plot_S/P                                 -0.751047                -0.705836
# Plot_Size_Factor                          0.969885                 0.981547
# Plot_Mom_Size                             0.946465                 0.958779
# Plot_Mom_Val                              0.859777                 0.887000
# Plot_Vol_EP_Size                          0.934430                 0.956096
# Plot_Mom_Sharpe_EP_Size_Factor            0.946085                 0.954927
# Plot_EP_Size                              0.944057                 0.960587
# Plot_Mom_Std                              0.892293                 0.898361
# Plot_Mom_Growth                           0.971233                 0.976191
# Plot_Mom_Size_Sales                       0.957511                 0.976827
# Plot_Mom_M_Size_Sales                     0.971458                 0.987927
# Plot_Mom_M_EPS                            0.848798                 0.877762
# Plot_Mom_Sharpe_Size_Sales                0.973797                 0.977347
# Plot_Mom_Std_Sales                        1.000000                 0.985704
# Plot_Mom_Size_Sales_Std                   0.985704                 1.000000
# Plot_Mom_Size_Std                         0.897659                 0.928057
# Plot_Mom_Size_Sales_EP                    0.969618                 0.980911
# Plot_Mom_Size_EPS                         0.968986                 0.975672
# Plot_Mom_Size_EP                          0.956847                 0.974057
# Plot_Mom_Vol_StDev                        0.887770                 0.916944
#
#                                 Plot_Mom_Size_Std  Plot_Mom_Size_Sales_EP  \
# Plot_Momentum                            0.933976                0.829950
# Plot_Mom_Sharpe                          0.879472                0.967051
# Plot_Mom_Slope                           0.907004                0.944669
# Plot_StDev                               0.883223                0.775580
# Plot_Sector_Return                       0.802457                0.939512
# Plot_Sales_Growth                        0.801426                0.608402
# Plot_OPM_Growth                          0.657183                0.458361
# Plot_EPS_Growth                          0.586173                0.412624
# Plot_EPS                                 0.585431                0.332411
# Plot_E/P                                 0.594298                0.372727
# Plot_PEG                                 0.773233                0.619959
# Plot_S/P                                -0.527346               -0.715539
# Plot_Size_Factor                         0.913987                0.984833
# Plot_Mom_Size                            0.902414                0.969695
# Plot_Mom_Val                             0.938472                0.903452
# Plot_Vol_EP_Size                         0.902366                0.975348
# Plot_Mom_Sharpe_EP_Size_Factor           0.889143                0.972465
# Plot_EP_Size                             0.907677                0.980901
# Plot_Mom_Std                             0.954104                0.873941
# Plot_Mom_Growth                          0.868865                0.953834
# Plot_Mom_Size_Sales                      0.903711                0.978545
# Plot_Mom_M_Size_Sales                    0.897567                0.985012
# Plot_Mom_M_EPS                           0.932330                0.895685
# Plot_Mom_Sharpe_Size_Sales               0.881269                0.991743
# Plot_Mom_Std_Sales                       0.897659                0.969618
# Plot_Mom_Size_Sales_Std                  0.928057                0.980911
# Plot_Mom_Size_Std                        1.000000                0.895276
# Plot_Mom_Size_Sales_EP                   0.895276                1.000000
# Plot_Mom_Size_EPS                        0.888633                0.984507
# Plot_Mom_Size_EP                         0.923167                0.981237
# Plot_Mom_Vol_StDev                       0.947720                0.896703
#
#                                 Plot_Mom_Size_EPS  Plot_Mom_Size_EP  \
# Plot_Momentum                            0.839588          0.883507
# Plot_Mom_Sharpe                          0.985472          0.969399
# Plot_Mom_Slope                           0.909198          0.918432
# Plot_StDev                               0.722464          0.785255
# Plot_Sector_Return                       0.973722          0.941175
# Plot_Sales_Growth                        0.621128          0.677163
# Plot_OPM_Growth                          0.450300          0.521205
# Plot_EPS_Growth                          0.445286          0.493792
# Plot_EPS                                 0.373988          0.458959
# Plot_E/P                                 0.356535          0.442234
# Plot_PEG                                 0.664686          0.714983
# Plot_S/P                                -0.776678         -0.710651
# Plot_Size_Factor                         0.983272          0.975459
# Plot_Mom_Size                            0.990603          0.991226
# Plot_Mom_Val                             0.900758          0.940746
# Plot_Vol_EP_Size                         0.980537          0.984899
# Plot_Mom_Sharpe_EP_Size_Factor           0.991775          0.988213
# Plot_EP_Size                             0.963419          0.969431
# Plot_Mom_Std                             0.854676          0.879952
# Plot_Mom_Growth                          0.940371          0.931546
# Plot_Mom_Size_Sales                      0.945319          0.952339
# Plot_Mom_M_Size_Sales                    0.969004          0.970249
# Plot_Mom_M_EPS                           0.894588          0.935831
# Plot_Mom_Sharpe_Size_Sales               0.979897          0.967177
# Plot_Mom_Std_Sales                       0.968986          0.956847
# Plot_Mom_Size_Sales_Std                  0.975672          0.974057
# Plot_Mom_Size_Std                        0.888633          0.923167
# Plot_Mom_Size_Sales_EP                   0.984507          0.981237
# Plot_Mom_Size_EPS                        1.000000          0.986591
# Plot_Mom_Size_EP                         0.986591          1.000000
# Plot_Mom_Vol_StDev                       0.917200          0.939515
#
#                                 Plot_Mom_Vol_StDev
# Plot_Momentum                             0.969850
# Plot_Mom_Sharpe                           0.926502
# Plot_Mom_Slope                            0.889874
# Plot_StDev                                0.785217
# Plot_Sector_Return                        0.847701
# Plot_Sales_Growth                         0.801372
# Plot_OPM_Growth                           0.621404
# Plot_EPS_Growth                           0.591217
# Plot_EPS                                  0.608180
# Plot_E/P                                  0.575824
# Plot_PEG                                  0.781662
# Plot_S/P                                 -0.624632
# Plot_Size_Factor                          0.912317
# Plot_Mom_Size                             0.934440
# Plot_Mom_Val                              0.954437
# Plot_Vol_EP_Size                          0.918743
# Plot_Mom_Sharpe_EP_Size_Factor            0.925348
# Plot_EP_Size                              0.895273
# Plot_Mom_Std                              0.912907
# Plot_Mom_Growth                           0.871206
# Plot_Mom_Size_Sales                       0.880007
# Plot_Mom_M_Size_Sales                     0.888735
# Plot_Mom_M_EPS                            0.950909
# Plot_Mom_Sharpe_Size_Sales                0.885194
# Plot_Mom_Std_Sales                        0.887770
# Plot_Mom_Size_Sales_Std                   0.916944
# Plot_Mom_Size_Std                         0.947720
# Plot_Mom_Size_Sales_EP                    0.896703
# Plot_Mom_Size_EPS                         0.917200
# Plot_Mom_Size_EP                          0.939515
# Plot_Mom_Vol_StDev                        1.000000
#
# [31 rows x 31 columns]
